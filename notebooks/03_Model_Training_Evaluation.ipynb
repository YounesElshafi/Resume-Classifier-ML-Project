# %% [markdown]
# ## 🤖 Model Training & Evaluation for Resume Classification

# %% [markdown]
# ### 1. Import Required Libraries

# %%
import pandas as pd
import numpy as np
import joblib
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2. Load Preprocessed Data

# %%
X_train = joblib.load('../models/X_train.pkl')
X_test = joblib.load('../models/X_test.pkl')
y_train = joblib.load('../models/y_train.pkl')
y_test = joblib.load('../models/y_test.pkl')

# %% [markdown]
# ### 3. Model Evaluation Function

# %%
def evaluate_model(model, name="Model"):
    """
    Train the model and evaluate it using accuracy, classification report, and confusion matrix.
    """
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    acc = accuracy_score(y_test, y_pred)
    print(f"\n📊 {name} Accuracy: {acc:.4f}")
    
    print("\n📝 Classification Report:")
    print(classification_report(y_test, y_pred))
    
    cm = confusion_matrix(y_test, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap="Blues", xticklabels=np.unique(y_test), yticklabels=np.unique(y_test))
    plt.title(f"{name} - Confusion Matrix")
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### 4. Train & Evaluate Multiple Models

# %%
evaluate_model(LogisticRegression(max_iter=1000), "Logistic Regression")
# Out:
# 📊 Logistic Regression Accuracy: 0.5294
#
# 📝 Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         2
#            1       0.00      0.00      0.00         1
#            2       0.50      1.00      0.67         1
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         1
#            5       1.00      1.00      1.00         1
#            6       0.50      1.00      0.67         2
#            7       0.40      1.00      0.57         2
#            8       0.00      0.00      0.00         1
#            9       1.00      0.50      0.67         2
#           10       0.00      0.00      0.00         1
#           11       0.00      0.00      0.00         1
#           12       1.00      1.00      1.00         2
#           13       1.00      1.00      1.00         2
#           14       0.50      1.00      0.67         1
# ...

# %%
evaluate_model(RandomForestClassifier(n_estimators=100, random_state=42), "Random Forest")
# Out:
# 📊 Random Forest Accuracy: 0.7647
#
# 📝 Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         2
#            1       1.00      1.00      1.00         1
#            2       0.50      1.00      0.67         1
#            3       0.00      0.00      0.00         1
#            4       1.00      1.00      1.00         1
#            5       1.00      1.00      1.00         1
#            6       1.00      0.50      0.67         2
#            7       1.00      1.00      1.00         2
#            8       0.00      0.00      0.00         1
#            9       0.50      0.50      0.50         2
#           10       1.00      1.00      1.00         1
#           11       1.00      1.00      1.00         1
#           12       0.67      1.00      0.80         2
#           13       1.00      1.00      1.00         2
#           14       0.50      1.00      0.67         1
# ...

# %%
evaluate_model(MultinomialNB(), "Naive Bayes")
# Out:
# 📊 Naive Bayes Accuracy: 0.3529
#
# 📝 Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.67      1.00      0.80         2
#            1       0.00      0.00      0.00         1
#            2       0.00      0.00      0.00         1
#            3       0.00      0.00      0.00         1
#            4       0.00      0.00      0.00         1
#            5       1.00      1.00      1.00         1
#            6       1.00      0.50      0.67         2
#            7       0.29      1.00      0.44         2
#            8       0.00      0.00      0.00         1
#            9       0.00      0.00      0.00         2
#           10       0.00      0.00      0.00         1
#           11       0.00      0.00      0.00         1
#           12       1.00      1.00      1.00         2
#           13       1.00      0.50      0.67         2
#           14       0.00      0.00      0.00         1
# ...

# %%
evaluate_model(KNeighborsClassifier(), "K-Nearest Neighbors")
# Out:
# 📊 K-Nearest Neighbors Accuracy: 0.8235
#
# 📝 Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         1
#            2       0.25      1.00      0.40         1
#            3       1.00      1.00      1.00         1
#            4       0.50      1.00      0.67         1
#            5       1.00      1.00      1.00         1
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         2
#            8       0.00      0.00      0.00         1
#            9       0.67      1.00      0.80         2
#           10       1.00      1.00      1.00         1
#           11       1.00      1.00      1.00         1
#           12       1.00      1.00      1.00         2
#           13       1.00      1.00      1.00         2
#           14       1.00      1.00      1.00         1
# ...

# %%
evaluate_model(OneVsRestClassifier(SVC()), "One-vs-Rest (SVC)")
# Out:
# 📊 One-vs-Rest (SVC) Accuracy: 0.7941
#
# 📝 Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         1
#            2       0.33      1.00      0.50         1
#            3       0.00      0.00      0.00         1
#            4       0.50      1.00      0.67         1
#            5       1.00      1.00      1.00         1
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         2
#            8       0.00      0.00      0.00         1
#            9       1.00      1.00      1.00         2
#           10       1.00      1.00      1.00         1
#           11       1.00      1.00      1.00         1
#           12       1.00      1.00      1.00         2
#           13       1.00      1.00      1.00         2
#           14       1.00      1.00      1.00         1
# ...

# %%
evaluate_model(OneVsRestClassifier(KNeighborsClassifier()), "One-vs-Rest (KNN)")
# Out:
# 📊 One-vs-Rest (KNN) Accuracy: 0.8235
#
# 📝 Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         1
#            2       0.50      1.00      0.67         1
#            3       0.00      0.00      0.00         1
#            4       1.00      1.00      1.00         1
#            5       1.00      1.00      1.00         1
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         2
#            8       1.00      1.00      1.00         1
#            9       1.00      0.50      0.67         2
#           10       1.00      1.00      1.00         1
#           11       1.00      1.00      1.00         1
#           12       1.00      1.00      1.00         2
#           13       1.00      1.00      1.00         2
#           14       1.00      1.00      1.00         1
# ...
